# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('/Users/chenwang/Dropbox/SDG_Adjusted_File_Daily.csv')

# %%
df1.head()
# Out:
#    Unnamed: 0   Timestamp Ticker          ISIN              Company_Name  \
# 0           0  2013-04-01      A  US00846U1016  agilent technologies inc
# 1           1  2013-04-02      A  US00846U1016  agilent technologies inc
# 2           2  2013-04-03      A  US00846U1016  agilent technologies inc
# 3           3  2013-04-04      A  US00846U1016  agilent technologies inc
# 4           4  2013-04-05      A  US00846U1016  agilent technologies inc
#
#    GICS Sector  SDG_1_ADJ  SDG_2_ADJ  SDG_3_ADJ  SDG_4_ADJ  ...  \
# 0  Health Care        NaN        NaN        NaN        NaN  ...
# 1  Health Care        NaN        NaN        NaN        NaN  ...
# 2  Health Care        NaN        NaN        NaN        NaN  ...
# 3  Health Care        NaN        NaN        NaN        NaN  ...
# 4  Health Care        NaN        NaN        NaN        NaN  ...
#
#    SDG_9_News_Volume  SDG_10_News_Volume  SDG_11_News_Volume  \
# 0                NaN                 NaN                 NaN
# ...

# %%
df2 = pd.read_csv('/Users/chenwang/Dropbox/SDG_Data_File_Daily.csv')

# %%
df2.head()
# Out:
#    Unnamed: 0   Timestamp Ticker          ISIN              Company_Name  \
# 0           0  2013-04-01      A  US00846U1016  agilent technologies inc
# 1           1  2013-04-02      A  US00846U1016  agilent technologies inc
# 2           2  2013-04-03      A  US00846U1016  agilent technologies inc
# 3           3  2013-04-04      A  US00846U1016  agilent technologies inc
# 4           4  2013-04-05      A  US00846U1016  agilent technologies inc
#
#    GICS Sector  SDG_1  SDG_2  SDG_3  SDG_4  ...  SDG_9_News_Volume  \
# 0  Health Care    NaN    NaN    NaN    NaN  ...                NaN
# 1  Health Care    NaN    NaN    NaN    NaN  ...                NaN
# 2  Health Care    NaN    NaN    NaN    NaN  ...                NaN
# 3  Health Care    NaN    NaN    NaN    NaN  ...                NaN
# 4  Health Care    NaN    NaN    NaN    NaN  ...                NaN
#
#    SDG_10_News_Volume  SDG_11_News_Volume  SDG_12_News_Volume  \
# ...

# %%
df3 = pd.read_csv('/Users/chenwang/Dropbox/Sentiment_Data_File_Daily.csv')
df3.head()
# Out:
#    Unnamed: 0   Timestamp Ticker          ISIN      Company_Name  GICS Sector  \
# 0           0  2013-04-01    AOS  US8318652091  a. o. smith corp  Industrials
# 1           1  2013-04-02    AOS  US8318652091  a. o. smith corp  Industrials
# 2           2  2013-04-03    AOS  US8318652091  a. o. smith corp  Industrials
# 3           3  2013-04-04    AOS  US8318652091  a. o. smith corp  Industrials
# 4           4  2013-04-05    AOS  US8318652091  a. o. smith corp  Industrials
#
#    Sentiment  STS  LTS  Sentiment_STD  Sentiment_News_Volume
# 0        NaN  NaN  NaN            NaN                    NaN
# 1        NaN  NaN  NaN            NaN                    NaN
# 2        NaN  NaN  NaN            NaN                    NaN
# 3        NaN  NaN  NaN            NaN                    NaN
# 4        NaN  NaN  NaN            NaN                    NaN

# %%
#all the tickers in the files
tickers = list(set(df3['Ticker'].tolist()))

# %%
# Time span
start = min(df3['Timestamp'])
end = max(df3['Timestamp'])

# %%
from pandas_datareader import data

# %%
#Get historical time series data from all the tickers in the files, including:
      #Daily prices
      #Earnings/Price Ratio 
      #Book Value/Price Ratio
#panel_data = data.DataReader(tickers, 'yahoo', start, end)

# %%
# Learning from warnings
# Failed to read symbol: '', replacing with NaN.
junk_list = ['RHT','S','AGN','AVP','ZAYO','BBT','TSS','APC','GGP','BRK/B','VIAB','JEC','DATA','TMK','CELG','BF/B','WFTIQ','SYMC','WBC','CBS','DNB','HCP','BHGE','FDC','DO','LPT']

# %%
tickers_new = list(set(tickers)-set(junk_list))

# %%
panel_data = data.DataReader(tickers_new, 'yahoo', start, end)

# %%
panel_data
# Out:
# Attributes  Adj Close                                                \
# Symbols           CTL         PNC        NBL         SWK        RRC
# Date
# 2013-04-01  18.551210   53.553322  52.027149   68.527077  77.689720
# 2013-04-02  18.721502   54.383595  51.973339   68.312447  76.490646
# 2013-04-03  18.657644   53.016079  51.686283   67.900414  73.966743
# 2013-04-04  19.168524   53.398659  50.551556   67.290932  73.986084
# 2013-04-05  19.216415   53.105618  50.040257   66.578476  76.510002
# ...               ...         ...        ...         ...        ...
# 2020-04-16   9.300661   88.601967   6.223841  105.674271   4.430000
# 2020-04-17   9.777618   99.327362   6.920912  111.447693   4.650000
# 2020-04-20   9.672688  100.354889   6.831289  109.407684   5.140000
# 2020-04-21   9.262505   96.880875   6.701832  105.307854   5.270000
# 2020-04-22   9.252966   96.783020   7.219656  106.327866   5.120000
#
# Attributes                                                          ...  \
# ...
